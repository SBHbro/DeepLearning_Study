# %%
from sklearn.externals import joblib
import pickle

model = joblib.load('model.pkl')
# model = pickle.load(open('model.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-6-233a650bcfdb> in <module>
#       2 import pickle
#       3
# ----> 4 model = joblib.load('model.pkl')
#       5 # model = pickle.load(open('model.pkl','rb'))
#
# d:\programdata\anaconda3\envs\maskrcnn\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     603                     return load_compatibility(fobj)
#     604
# --> 605                 obj = _unpickle(fobj, filename, mmap_mode)
#     606
#     607     return obj
#
# d:\programdata\anaconda3\envs\maskrcnn\lib\site-packages\joblib\numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     527     obj = None
#     528     try:
# --> 529         obj = unpickler.load()
#     530         if unpickler.compat_mode:
#     531             warnings.warn("The file '%s' has been generated with a "
#
# ...

# %%
import datetime

def get_now():
    """
        현재 시스템 시간을 datetime형으로 반환
    """
    return datetime.datetime.now()

def get_now_timestamp():
    """
        현재 시스템 시간을 POSIX timestamp float형으로 반환
    """
    return get_now().timestamp()

# %%
ts = get_now_timestamp()
print(ts)
# Out:
# 1573111022.270712

# %%
date = datetime.datetime.fromtimestamp(int(ts)).strftime('%Y-%m-%d %H-%M-%S')

# %%
print(date)
# Out:
# 2019-11-07 16-17-02

# %%
from scipy import misc


image = misc.imread('image.jpg')
# Out:
# d:\programdata\anaconda3\envs\maskrcnn\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis('off')
plt.savefig(fname='test.jpg', bbox_inches='tight', pad_inches=0)

# %%
image.save('tst')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-3c7cfd6548fa> in <module>
# ----> 1 image.save('tst')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'
